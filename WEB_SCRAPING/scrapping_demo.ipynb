# %% [markdown]
# I want to scrap the data from the website and create Chunks and print them. I will use the requests and BeautifulSoup libraries to do this. I will also use the pandas library to store the data in a csv file.

# %%
print("hello jupiter")
# Out:
# hello jupiter
